# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

print("All libraries were loaded successfully.")
# Out:
# All libraries were loaded successfully.

# %%
data_path = '../data/raw/watch_price_raw.csv'

try:
    df = pd.read_csv(data_path)
    print(f"Dataset loaded successfully. {df.shape[0]} rows, {df.shape[1]} columns.")
except FileNotFoundError:
    print(f"ERROR: File not found. Check path '{data_path}'.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 data_path = '../data/raw/watch_price_raw.csv'
#       3 try:
# ----> 4     df = pd.read_csv(data_path)
#       5     print(f"Dataset loaded successfully. {df.shape[0]} rows, {df.shape[1]} columns.")
#       6 except FileNotFoundError:
#
# NameError: name 'pd' is not defined

# %%
df.head()

# %%
df.tail()

# %%
print("Dataset Information (df.info()):")
df.info()

# %%
print("\nNumeric Columns Summary (df.describe()):")
df.describe().apply(lambda s: s.apply('{0:.2f}'.format))

# %%
print("\nCategorical Columns Summary (df.describe(include='object')):")
df.describe(include=['object'])
